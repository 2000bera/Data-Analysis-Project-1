# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plot
import numpy as np
import warnings

# %%
# %matplotlib inline
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/drive/Othercomputers/My Laptop/Desktop/iTECH1.csv')

# %%
# THIS IS THE DUMMY DATA I CREATED BY MYSELF TO DO EDA


df.head()
# Out:
#    ID  Job_ID First_Name Last_Name        Full_Name            Job_Position  \
# 0   1    1001     Layola      Bera      Layola Bera            Data Analyst
# 1   2    1003       Ealy   Michael     Ealy Michael        Finacial Analyst
# 2   3    1002      Kevin      Hart       Kevin Hart  Human Resource Manager
# 3   4    1001     Sophia  Anderson  Sophia Anderson           IT Technician
# 4   5    1004       Liam    Harris      Liam Harris                  Lawyer
#
#                Department Date_Employed Salary_Annually
# 0                      IT     7/10/2018     R495,690.00
# 1  Finance and Accounting     6/11/2022     R355,690.00
# 2                      HR     7/12/2018     R659,321.00
# 3                      IT     7/10/2018     R250,432.00
# 4                   Legal     7/14/2020     R350,000.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               26 non-null     int64
#  1   Job_ID           26 non-null     int64
#  2   First_Name       26 non-null     object
#  3   Last_Name        26 non-null     object
#  4   Full_Name        26 non-null     object
#  5   Job_Position     26 non-null     object
#  6   Department       26 non-null     object
#  7   Date_Employed    26 non-null     object
#  8   Salary_Annually  26 non-null     object
# dtypes: int64(2), object(7)
# memory usage: 2.0+ KB

# %%
df.shape
# Out:
# (26, 9)

# %%
df['Date_Employed'] = pd.to_datetime(df['Date_Employed'])
df['Salary_Annually'] = df['Salary_Annually'].str.replace('R', '').str.replace(',', '').astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               26 non-null     int64
#  1   Job_ID           26 non-null     int64
#  2   First_Name       26 non-null     object
#  3   Last_Name        26 non-null     object
#  4   Full_Name        26 non-null     object
#  5   Job_Position     26 non-null     object
#  6   Department       26 non-null     object
#  7   Date_Employed    26 non-null     datetime64[ns]
#  8   Salary_Annually  26 non-null     float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(5)
# memory usage: 2.0+ KB

# %%
df.head()
# Out:
#    ID  Job_ID First_Name Last_Name        Full_Name            Job_Position  \
# 0   1    1001     Layola      Bera      Layola Bera            Data Analyst
# 1   2    1003       Ealy   Michael     Ealy Michael        Finacial Analyst
# 2   3    1002      Kevin      Hart       Kevin Hart  Human Resource Manager
# 3   4    1001     Sophia  Anderson  Sophia Anderson           IT Technician
# 4   5    1004       Liam    Harris      Liam Harris                  Lawyer
#
#                Department Date_Employed  Salary_Annually
# 0                      IT    2018-07-10         495690.0
# 1  Finance and Accounting    2022-06-11         355690.0
# 2                      HR    2018-07-12         659321.0
# 3                      IT    2018-07-10         250432.0
# 4                   Legal    2020-07-14         350000.0

# %%
df.isnull().sum()
# Out:
# ID                 0
# Job_ID             0
# First_Name         0
# Last_Name          0
# Full_Name          0
# Job_Position       0
# Department         0
# Date_Employed      0
# Salary_Annually    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# ID                 26
# Job_ID             10
# First_Name         26
# Last_Name          26
# Full_Name          26
# Job_Position       19
# Department         10
# Date_Employed      18
# Salary_Annually    21
# dtype: int64

# %%
round(df['Salary_Annually'].describe(),2)
# Out:
# count        26.00
# mean     288595.46
# std      141026.85
# min      106781.00
# 25%      200375.00
# 50%      279988.50
# 75%      350000.00
# max      659321.00
# Name: Salary_Annually, dtype: float64

# %%
df['Department'].value_counts()
# Out:
# Department
# IT                        5
# Finance and Accounting    3
# HR                        3
# Legal                     3
# Customer Support          3
# Operations                2
# Marketing                 2
# Supply Chain              2
# Design                    2
# Quality Assurance         1
# Name: count, dtype: int64

# %%
df.sort_values(by='Department', ascending=False)
# Out:
#     ID  Job_ID First_Name   Last_Name         Full_Name  \
# 8    9    1006        Mia      Robert        Mia Robert
# 16  17    1006       Ella      Foster       Ella Foster
# 13  14    1009  Charlotte      Turner  Charlotte Turner
# 21  22    1007       Will       Smith        Will Smith
# 5    6    1007     Olivia    Campbell   Olivia Campbell
# 14  15    1010      Henry       Scott       Henry Scott
# 7    8    1010      Lucas       Lewis       Lucas Lewis
# 22  23    1004       Vuyo       Lundi        Vuyo Lundi
# 4    5    1004       Liam      Harris       Liam Harris
# 9   10    1004      James      Walker      James Walker
# 18  19    1001       Owen      Brooks       Owen Brooks
# 0    1    1001     Layola        Bera       Layola Bera
# 11  12    1001    Isabell      Miller    Isabell Miller
# 3    4    1001     Sophia    Anderson   Sophia Anderson
# 25  26    1001      Linda      Xumalo      Linda Xumalo
# 10  11    1002     Amelia      Carter     Amelia Carter
# ...

# %%
df.sort_values(by='Salary_Annually', ascending=False)
# Out:
#     ID  Job_ID First_Name   Last_Name         Full_Name  \
# 2    3    1002      Kevin        Hart        Kevin Hart
# 13  14    1009  Charlotte      Turner  Charlotte Turner
# 0    1    1001     Layola        Bera       Layola Bera
# 11  12    1001    Isabell      Miller    Isabell Miller
# 1    2    1003       Ealy     Michael      Ealy Michael
# 24  25    1003        Zoe      Parker        Zoe Parker
# 22  23    1004       Vuyo       Lundi        Vuyo Lundi
# 4    5    1004       Liam      Harris       Liam Harris
# 18  19    1001       Owen      Brooks       Owen Brooks
# 9   10    1004      James      Walker      James Walker
# 10  11    1002     Amelia      Carter     Amelia Carter
# 23  24    1002     Sifiso       Monde      Sifiso Monde
# 25  26    1001      Linda      Xumalo      Linda Xumalo
# 3    4    1001     Sophia    Anderson   Sophia Anderson
# 5    6    1007     Olivia    Campbell   Olivia Campbell
# 12  13    1005      Aiden       Clark       Aiden Clark
# ...

# %%
df.sort_values(by='Date_Employed', ascending=False)
# Out:
#     ID  Job_ID First_Name   Last_Name         Full_Name  \
# 14  15    1010      Henry       Scott       Henry Scott
# 17  18    1005     Amanda     Dlamini    Amanda Dlamini
# 12  13    1005      Aiden       Clark       Aiden Clark
# 8    9    1006        Mia      Robert        Mia Robert
# 16  17    1006       Ella      Foster       Ella Foster
# 15  16    1003      Chloe       Adams       Chloe Adams
# 7    8    1010      Lucas       Lewis       Lucas Lewis
# 1    2    1003       Ealy     Michael      Ealy Michael
# 22  23    1004       Vuyo       Lundi        Vuyo Lundi
# 4    5    1004       Liam      Harris       Liam Harris
# 23  24    1002     Sifiso       Monde      Sifiso Monde
# 21  22    1007       Will       Smith        Will Smith
# 10  11    1002     Amelia      Carter     Amelia Carter
# 24  25    1003        Zoe      Parker        Zoe Parker
# 19  20    1008     Luyolo      Ndlovu     Luyolo Ndlovu
# 20  21    1008       Jack  Richardson   Jack Richardson
# ...

# %%
plot.figure(figsize=(10,5))
sn.boxplot(data=df, x='Salary_Annually')
plot.show()

# %%
sn.distplot(df['Salary_Annually'])
plot.show()

# %%
sn.scatterplot(data=df, x='Salary_Annually', y='Department')
plot.show()

# %%
plot.figure(figsize=(15,7))
sn.countplot(data=df, x='Department')
plot.show()
